# %% [markdown]
# <a href="https://colab.research.google.com/github/davro76/BERINGS-EasyStat/blob/main/Welcome_To_Colaboratory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install, upgrade, and upload the required librairies, and dependencies
# !pip install tweepy
# !pip install tweepy --upgrade
# !pip install better_profanity
import tweepy
client = tweepy.Client(bearer_token='AAAAAAAAAAAAAAAAAAAAAMiOiwEAAAAA3EknKKW97OXr0BfabeYo8vmiCHU%3Dyxxy5tCQGb8rLY9TLxoc2R8TGGbaiWpk3KbCU3P8SDC9k0yJ8s')
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tweepy in /usr/local/lib/python3.7/dist-packages (3.10.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in /usr/local/lib/python3.7/dist-packages (from tweepy) (2.23.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tweepy) (1.3.1)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tweepy) (1.15.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->tweepy) (3.2.2)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy) (2022.9.24)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy) (1.7.1)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tweepy in /usr/local/lib/python3.7/dist-packages (3.10.0)
# Collecting tweepy
#   Downloading tweepy-4.12.1-py3-none-any.whl (101 kB)
#      |████████████████████████████████| 101 kB 4.0 MB/s
# Requirement already satisfied: requests-oauthlib<2,>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from tweepy) (1.3.1)
# Collecting requests<3,>=2.27.0
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 1.2 MB/s
# Requirement already satisfied: oauthlib<4,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from tweepy) (3.2.2)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.27.0->tweepy) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.27.0->tweepy) (1.24.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.27.0->tweepy) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.27.0->tweepy) (2022.9.24)
# Installing collected packages: requests, tweepy
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: tweepy
#     Found existing installation: tweepy 3.10.0
#     Uninstalling tweepy-3.10.0:
#       Successfully uninstalled tweepy-3.10.0
# Successfully installed requests-2.28.1 tweepy-4.12.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting better_profanity
#   Downloading better_profanity-0.7.0-py3-none-any.whl (46 kB)
#      |████████████████████████████████| 46 kB 2.8 MB/s
# Installing collected packages: better-profanity
# Successfully installed better-profanity-0.7.0

# %%
import tweepy

your_query = "Joseph Robinette Biden Jr"
query = your_query + ' -is:retweet'

tweets = client.search_recent_tweets(query=query, tweet_fields=['context_annotations', 'created_at'], max_results=100)

for tweet in tweets.data:
    print(tweet.text)
    if len(tweet.context_annotations) > 0:
        print(tweet.context_annotations)
# Out:
# Joseph Robinette Biden Jr. (born November 20, 1942), an American politician who is the 46th and current president of the United States.
# [{'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '35', 'name': 'Politician', 'description': 'Politicians in the world, like Joe Biden'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}]
# @trumwill @CJohnsonYCCD I would say my only strong opinion of Joseph Robinette Biden Jr. is he's never met a hot mic he didn't like.
# [{'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '35', 'name': 'Politician', 'description': 'Politicians in the world, like Joe Biden'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}]
# Joseph Robinette Biden Jr https://t.co/URcdzeOv0X
# [{'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '35', 'name': 'Politician', 'description': 'Politicians in the world, like Joe Biden'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '847878884917886977', 'name': 'Politics', 'description': 'Politics'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1070032753834438656', 'name': 'Political figures', 'description': 'Politician'}}]
# @BeschlossDC You’re a fraud of epic proportions. You vastly overstate the situation. The biggest threats to democracy are things like our moral and social decline, the staggering national debt, and corrupt political “lifers” like Joseph Robinette Biden, Jr.
# [{'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '35', 'name': 'Politician', 'description': 'Politicians in the world, like Joe Biden'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '847511168268644352', 'name': 'Global Economy', 'description': 'Conversation about global finance and economies.'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '847878884917886977', 'name': 'Politics', 'description': 'Politics'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '900740740468191232', 'name': 'Political issues', 'description': 'Political issues'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1070032753834438656', 'name': 'Political figures', 'description': 'Politician'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1291447199595782144', 'name': 'United States politics'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1518689897296453633', 'name': 'United States political issues'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1561886046505222144', 'name': 'National debt of the United States'}}]
# Folks, Joseph Robinette Biden Jr knows what he’s doing! I stand with @potus all the way to a second term. Don’t care if he’s as old as Noah!
# [{'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '35', 'name': 'Politician', 'description': 'Politicians in the world, like Joe Biden'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '847878884917886977', 'name': 'Politics', 'description': 'Politics'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1070032753834438656', 'name': 'Political figures', 'description': 'Politician'}}]
# Thank you, President Joseph Robinette Biden, Jr! https://t.co/ljgFCboAd2
# [{'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '35', 'name': 'Politician', 'description': 'Politicians in the world, like Joe Biden'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '847878884917886977', 'name': 'Politics', 'description': 'Politics'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1070032753834438656', 'name': 'Political figures', 'description': 'Politician'}}]
# @BeschlossDC Our planet, and thus humankind, are far better off because of Joseph Robinette Biden, Jr. For how many people throughout history can such a statement be made?
# [{'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '35', 'name': 'Politician', 'description': 'Politicians in the world, like Joe Biden'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '847878884917886977', 'name': 'Politics', 'description': 'Politics'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1070032753834438656', 'name': 'Political figures', 'description': 'Politician'}}]
# @JoJoFromJerz There’s never been a more openly (thanks to Hunter) corrupt politician than Joseph Robinette Biden Jr.
# @trumwill @CJohnsonYCCD I'm a "Vote D or democracy is at risk Democrat", and even I don't have strong opinions on Joseph Robinette Biden Jr.
# [{'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '35', 'name': 'Politician', 'description': 'Politicians in the world, like Joe Biden'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '847878884917886977', 'name': 'Politics', 'description': 'Politics'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1070032753834438656', 'name': 'Political figures', 'description': 'Politician'}}]
# @rottingrealgirl everyone expect joseph robinette biden jr
# [{'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '35', 'name': 'Politician', 'description': 'Politicians in the world, like Joe Biden'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '847878884917886977', 'name': 'Politics', 'description': 'Politics'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1070032753834438656', 'name': 'Political figures', 'description': 'Politician'}}]
# @CJohnsonYCCD I supported him in the primary and the general and I'm hardly a normie but even I don't have strong opinions on Joseph Robinette Biden Jr.
# [{'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '35', 'name': 'Politician', 'description': 'Politicians in the world, like Joe Biden'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '847878884917886977', 'name': 'Politics', 'description': 'Politics'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1070032753834438656', 'name': 'Political figures', 'description': 'Politician'}}]
# @BuzzPatterson The U.S. has a pretty great leader right now in Joseph Robinette Biden Jr. From the midterm results, it seems like a lot of people feel the way I do.
# [{'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '35', 'name': 'Politician', 'description': 'Politicians in the world, like Joe Biden'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '847878884917886977', 'name': 'Politics', 'description': 'Politics'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1070032753834438656', 'name': 'Political figures', 'description': 'Politician'}}]
# Joseph Robinette Biden Jr. https://t.co/mgzbgZI3sA
# [{'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '35', 'name': 'Politician', 'description': 'Politicians in the world, like Joe Biden'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '847878884917886977', 'name': 'Politics', 'description': 'Politics'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1070032753834438656', 'name': 'Political figures', 'description': 'Politician'}}]
# Joseph Robinette Biden Jr. (born November 20, 1942), the 46th (and current) president of the United States.
#
# Donald John Trump (born June 14, 1946), the 45th president of the United States (from January 20, 2017 – January 20, 2021).
# [{'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '799022225751871488', 'name': 'Donald Trump', 'description': '45th US President, Donald Trump'}}, {'domain': {'id': '35', 'name': 'Politician', 'description': 'Politicians in the world, like Joe Biden'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '35', 'name': 'Politician', 'description': 'Politicians in the world, like Joe Biden'}, 'entity': {'id': '799022225751871488', 'name': 'Donald Trump', 'description': '45th US President, Donald Trump'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '799022225751871488', 'name': 'Donald Trump', 'description': '45th US President, Donald Trump'}}]
# @lindyli Joseph Robinette Biden Jr.comrade
# [{'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '35', 'name': 'Politician', 'description': 'Politicians in the world, like Joe Biden'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '847878884917886977', 'name': 'Politics', 'description': 'Politics'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1070032753834438656', 'name': 'Political figures', 'description': 'Politician'}}]
# Y'all doubted (now POTUS) Joseph Robinette Biden Jr. on August 11, 2020 too. https://t.co/37ibAbd1AZ
# [{'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '35', 'name': 'Politician', 'description': 'Politicians in the world, like Joe Biden'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '847878884917886977', 'name': 'Politics', 'description': 'Politics'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1070032753834438656', 'name': 'Political figures', 'description': 'Politician'}}]
# Joseph Robinette Biden, Jr, couramment appelé Joe Biden (/d͡ʒoʊ ˈbaɪ.dən/a), né le 20 novembre 1942 à Scranton (Pennsylvanie), est un homme d'État américain. 47e vice-président des États-Unis de 2009 à 2017, il est le 46e président des États-Unis depuis 2021.
# &gt; 80 years.
# &gt; 65 y.
# [{'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '35', 'name': 'Politician', 'description': 'Politicians in the world, like Joe Biden'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '847878884917886977', 'name': 'Politics', 'description': 'Politics'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1070032753834438656', 'name': 'Political figures', 'description': 'Politician'}}]
# @TeddyBEquality @Anais126 @ChrisJustice01 @DianeGhedi @RonFilipkowski A1. Merrick Brian Garland
# A2. Joseph Robinette Biden Jr.
#
# Q3: Why hasn't Merrick Garland indicted Trump?
# A3: Joseph Robinette Biden Jr.
#
# Biden is a smoother liar but he's actually governing far to the right of Drumpf - which is why Wall Street installed him.
# [{'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '1363864845783683085', 'name': 'Merrick Garland'}}, {'domain': {'id': '35', 'name': 'Politician', 'description': 'Politicians in the world, like Joe Biden'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '847878884917886977', 'name': 'Politics', 'description': 'Politics'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1070032753834438656', 'name': 'Political figures', 'description': 'Politician'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1363864845783683085', 'name': 'Merrick Garland'}}]
# @dbongino Sorry may be the BEST in many generations and his name is Joseph Robinette Biden Jr. and unlike you he does not smoke Donald Trump's pole as you do!
# [{'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '1060278893905534977', 'name': 'Dan Bongino', 'description': 'Dan Bongino'}}, {'domain': {'id': '35', 'name': 'Politician', 'description': 'Politicians in the world, like Joe Biden'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '94', 'name': 'Journalist', 'description': "A journalist like 'Anderson Cooper'"}, 'entity': {'id': '1060278893905534977', 'name': 'Dan Bongino', 'description': 'Dan Bongino'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '847878884917886977', 'name': 'Politics', 'description': 'Politics'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1046545033657081857', 'name': 'News', 'description': 'News'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1060278893905534977', 'name': 'Dan Bongino', 'description': 'Dan Bongino'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1070032753834438656', 'name': 'Political figures', 'description': 'Politician'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1074755369530880001', 'name': 'Journalists', 'description': 'Journalism'}}]
# Joseph Robinette Biden Jr. in all his fullness. May God guide you like it has all your life. #AMDG https://t.co/tEG5evc8F4
# [{'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '35', 'name': 'Politician', 'description': 'Politicians in the world, like Joe Biden'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '847878884917886977', 'name': 'Politics', 'description': 'Politics'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1070032753834438656', 'name': 'Political figures', 'description': 'Politician'}}]
# @Jeffdc5 Oh my, he must take to his bed with the vapors. Whatever shall Joseph Robinette Biden Jr do?
# [{'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '35', 'name': 'Politician', 'description': 'Politicians in the world, like Joe Biden'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '847878884917886977', 'name': 'Politics', 'description': 'Politics'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1070032753834438656', 'name': 'Political figures', 'description': 'Politician'}}]
# 例えば現米大統領がもし日本に在留することになったとして、あその通名は「ジョー・バイデン」になるだろう。
# で、民族名は「ジョセフ・ロビネット・バイデン・ジュニア」でええんかいなあ。それとも「Joseph Robinette Biden Jr.」やろか。
# [{'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '35', 'name': 'Politician', 'description': 'Politicians in the world, like Joe Biden'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1400506348727504906', 'name': 'Living abroad'}}]
# Bitch McShitface will *not* be stealing any court seats from President Joseph Robinette Biden Jr.! We got a Blue Wall in the Senate - now let's keep Georgia too!
# https://t.co/F7vIYuFc67
# [{'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '29', 'name': 'Events [Entity Service]', 'description': 'Real world events. '}, 'entity': {'id': '1572960636887146496', 'name': "Georgia's U.S. Senate election, 2022"}}, {'domain': {'id': '35', 'name': 'Politician', 'description': 'Politicians in the world, like Joe Biden'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '38', 'name': 'Political Race', 'description': ''}, 'entity': {'id': '1572960636887146496', 'name': "Georgia's U.S. Senate election, 2022"}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '847878884917886977', 'name': 'Politics', 'description': 'Politics'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1070032753834438656', 'name': 'Political figures', 'description': 'Politician'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1291447199595782144', 'name': 'United States politics'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1518940645343125504', 'name': 'United States political events'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1526278121527205889', 'name': '2022 United States midterm elections'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1572960636887146496', 'name': "Georgia's U.S. Senate election, 2022"}}, {'domain': {'id': '159', 'name': 'States', 'description': 'States, provinces, or prefectures, like California or Fukushima Prefecture'}, 'entity': {'id': '1004436112062812160', 'name': 'Georgia', 'description': 'Georgia'}}, {'domain': {'id': '29', 'name': 'Events [Entity Service]', 'description': 'Real world events. '}, 'entity': {'id': '1142039239485341696', 'name': "Georgia's parliamentary speaker resigns following protests", 'description': "Georgia's parliamentary speaker resigns following protests"}}]
# This is not encouraging for Democrats in 2024, but also: if we've learned one thing, you cannot count out Joseph Robinette Biden Jr. https://t.co/kGHaW2rHR0
# [{'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '35', 'name': 'Politician', 'description': 'Politicians in the world, like Joe Biden'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '847878884917886977', 'name': 'Politics', 'description': 'Politics'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1070032753834438656', 'name': 'Political figures', 'description': 'Politician'}}]
# @bjpluslj @sayitnspinit Nothing about that lying con man is good. Ask Ukraine about what Biden and Obama did to their peaceful country. Ask Afghanistan. Biden is all about cartels and money laundering, drug money, dead baby money, Senator Joseph Robinette Biden, Jr is a hateful, racist thief.
# [{'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '35', 'name': 'Politician', 'description': 'Politicians in the world, like Joe Biden'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '847878884917886977', 'name': 'Politics', 'description': 'Politics'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1070032753834438656', 'name': 'Political figures', 'description': 'Politician'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1427352573401452555', 'name': 'Crisis in Afghanistan'}}, {'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '10038764303', 'name': 'Barack Obama', 'description': 'Former US President Barack Obama'}}, {'domain': {'id': '35', 'name': 'Politician', 'description': 'Politicians in the world, like Joe Biden'}, 'entity': {'id': '10038764303', 'name': 'Barack Obama', 'description': 'Former US President Barack Obama'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '10038764303', 'name': 'Barack Obama', 'description': 'Former US President Barack Obama'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '847878884917886977', 'name': 'Politics', 'description': 'Politics'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1070032753834438656', 'name': 'Political figures', 'description': 'Politician'}}]
# @SusanInDelaware @JacobRubashkin @WHCOS While the haters are busy screaming “too old,” and after a lifetime of trials and tribulations, it just might be that Joseph Robinette Biden Jr. is actually hitting his stride, right here on the eve of his 80th birthday. https://t.co/I0m9szqE7Y
# [{'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '35', 'name': 'Politician', 'description': 'Politicians in the world, like Joe Biden'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '847878884917886977', 'name': 'Politics', 'description': 'Politics'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1070032753834438656', 'name': 'Political figures', 'description': 'Politician'}}]
# Catherine Cortez Masto’s phone is currently lighting up with a call from Joseph Robinette Biden Jr.
# [{'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '29', 'name': 'Events [Entity Service]', 'description': 'Real world events. '}, 'entity': {'id': '1526278121527205889', 'name': '2022 United States midterm elections'}}, {'domain': {'id': '29', 'name': 'Events [Entity Service]', 'description': 'Real world events. '}, 'entity': {'id': '1572962021129084928', 'name': "Nevada's U.S. Senate election, 2022"}}, {'domain': {'id': '35', 'name': 'Politician', 'description': 'Politicians in the world, like Joe Biden'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '38', 'name': 'Political Race', 'description': ''}, 'entity': {'id': '1526278121527205889', 'name': '2022 United States midterm elections'}}, {'domain': {'id': '38', 'name': 'Political Race', 'description': ''}, 'entity': {'id': '1572962021129084928', 'name': "Nevada's U.S. Senate election, 2022"}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '847878884917886977', 'name': 'Politics', 'description': 'Politics'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1070032753834438656', 'name': 'Political figures', 'description': 'Politician'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1291447199595782144', 'name': 'United States politics'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1488973753274929152', 'name': 'Political events'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1518940645343125504', 'name': 'United States political events'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1526278121527205889', 'name': '2022 United States midterm elections'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1572962021129084928', 'name': "Nevada's U.S. Senate election, 2022"}}, {'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '890265874191470592', 'name': 'Catherine Cortez Masto', 'description': 'US Senator Catherine Cortez Masto (NV)'}}, {'domain': {'id': '35', 'name': 'Politician', 'description': 'Politicians in the world, like Joe Biden'}, 'entity': {'id': '890265874191470592', 'name': 'Catherine Cortez Masto', 'description': 'US Senator Catherine Cortez Masto (NV)'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '847878884917886977', 'name': 'Politics', 'description': 'Politics'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '890265874191470592', 'name': 'Catherine Cortez Masto', 'description': 'US Senator Catherine Cortez Masto (NV)'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1070032753834438656', 'name': 'Political figures', 'description': 'Politician'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1291447199595782144', 'name': 'United States politics'}}, {' ...
# @Leftisaids @AnnLesbyPhD @michaeljknowles Actually she got to the top of the forgiveness line I heard and got her debt erased by his magnificence one of the best presidents in US history Joseph Robinette Biden Jr...
# [{'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '35', 'name': 'Politician', 'description': 'Politicians in the world, like Joe Biden'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '847878884917886977', 'name': 'Politics', 'description': 'Politics'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1070032753834438656', 'name': 'Political figures', 'description': 'Politician'}}]
# Assuming anyone normal has strong opinions about Joseph Robinette Biden Jr. was an obvious mistake from the jump. https://t.co/Lg6ipA9ien
# [{'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '35', 'name': 'Politician', 'description': 'Politicians in the world, like Joe Biden'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '847878884917886977', 'name': 'Politics', 'description': 'Politics'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1070032753834438656', 'name': 'Political figures', 'description': 'Politician'}}, {'domain': {'id': '159', 'name': 'States', 'description': 'States, provinces, or prefectures, like California or Fukushima Prefecture'}, 'entity': {'id': '1016387791591096320', 'name': 'Wisconsin', 'description': 'Wisconsin'}}]
# GOD BLESS JOSEPH ROBINETTE BIDEN JR.
#
# RETWEET IF YOU AGREE 🇺🇸
# [{'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '35', 'name': 'Politician', 'description': 'Politicians in the world, like Joe Biden'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '847878884917886977', 'name': 'Politics', 'description': 'Politics'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1070032753834438656', 'name': 'Political figures', 'description': 'Politician'}}]
# @ajbutdownbad by Joseph Robinette Biden Jr. himself https://t.co/V2iJ42eu4t
# [{'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '35', 'name': 'Politician', 'description': 'Politicians in the world, like Joe Biden'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '847878884917886977', 'name': 'Politics', 'description': 'Politics'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1070032753834438656', 'name': 'Political figures', 'description': 'Politician'}}]
# @Shaykay1717 @0liviajulianna Olivia,
#
# By 2024 Joseph Robinette Biden Jr., @JoeBiden WILL BE Placed On House Arrest for TREASON and due to his Mental Illness, will continue to believe HE IS STILL a Senator ... https://t.co/78Eb0LNYVI
# [{'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '35', 'name': 'Politician', 'description': 'Politicians in the world, like Joe Biden'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '46', 'name': 'Business Taxonomy', 'description': 'Categories within Brand Verticals that narrow down the scope of Brands'}, 'entity': {'id': '1557696940178935808', 'name': 'Gaming Business', 'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to offline and online games such as gaming consoles, tabletop games, video game publishers'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '847878884917886977', 'name': 'Politics', 'description': 'Politics'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1070032753834438656', 'name': 'Political figures', 'description': 'Politician'}}]
# Yes, DeSantis definitely lacks the powerful charisma of alpha male Joseph Robinette Biden, Jr. https://t.co/Uxaf0x1WRN
# ...
# @UrbanPioneerz Inflation itself, yes, it's a word in the dictionary. President Joseph Robinette Biden Jr. signed an executive order that directly impacted my free spending funds. MY economy. Whatever term you want, but $4+ at the pumps raised prices for everything transported. Too simple?
# [{'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '35', 'name': 'Politician', 'description': 'Politicians in the world, like Joe Biden'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '67', 'name': 'Interests and Hobbies', 'description': 'Interests, opinions, and behaviors of individuals, groups, or cultures; like Speciality Cooking or Theme Parks'}, 'entity': {'id': '1486458201117642754', 'name': 'Inflation'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '847878884917886977', 'name': 'Politics', 'description': 'Politics'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '900740740468191232', 'name': 'Political issues', 'description': 'Political issues'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1070032753834438656', 'name': 'Political figures', 'description': 'Politician'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1291447199595782144', 'name': 'United States politics'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1518689897296453633', 'name': 'United States political issues'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1559626214846869504', 'name': 'Inflation in the United States'}}]
# @WhiteHouse The Racist Fascist Bigot Joseph Robinette Biden Jr lies again.  Nothing new.
# [{'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '35', 'name': 'Politician', 'description': 'Politicians in the world, like Joe Biden'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '847878884917886977', 'name': 'Politics', 'description': 'Politics'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1070032753834438656', 'name': 'Political figures', 'description': 'Politician'}}, {'domain': {'id': '88', 'name': 'Political Body', 'description': 'A section of a government, like The Supreme Court'}, 'entity': {'id': '871795678447456256', 'name': 'The White House', 'description': 'Conversation from and about the White House, both as a destination and as political voice'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '847878884917886977', 'name': 'Politics', 'description': 'Politics'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '871795678447456256', 'name': 'The White House', 'description': 'Conversation from and about the White House, both as a destination and as political voice'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1068583660914266113', 'name': 'Government institutions', 'description': 'Political Body'}}]
# If only kids said this to Joe Biden in public. 😏
#
# #JoeBiden ✘ #Children | Democrats
# kid children youngster park school
# boy girl stranger weirdo playground
# person joseph robinette biden jr
# #Creepy #President #Odd #Vote
# https://t.co/TFlui38SA3
# [{'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '35', 'name': 'Politician', 'description': 'Politicians in the world, like Joe Biden'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '847878884917886977', 'name': 'Politics', 'description': 'Politics'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1070032753834438656', 'name': 'Political figures', 'description': 'Politician'}}]
# @1GigiAlexander @donwinslow @POTUS Well said, my dear.  I agree completely with your assessment of JOSEPH ROBINETTE BIDEN, Jr..  He is doing the job under incredible pressures from all sides.  Kudos to him!!!
# [{'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '35', 'name': 'Politician', 'description': 'Politicians in the world, like Joe Biden'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '847878884917886977', 'name': 'Politics', 'description': 'Politics'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1070032753834438656', 'name': 'Political figures', 'description': 'Politician'}}]
# ¿Qué es peor, un ultraconservador o un libertador dogmático?
#
# Lo pregunto por los papeles políticos y sociales que han adoptado el expresidente Donald John Trump (ultraconservador) y el presidente Joseph Robinette Biden Jr (libertador dogmático).
# [{'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '35', 'name': 'Politician', 'description': 'Politicians in the world, like Joe Biden'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '847878884917886977', 'name': 'Politics', 'description': 'Politics'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1070032753834438656', 'name': 'Political figures', 'description': 'Politician'}}]
# @KKCarolHaynes something comes out about Trump every day regardless of President Joseph Robinette Biden Jr's fortunes.  Trump is under investigation by every law enforcement agency in every jurisdiction he crimes in.  He might be guilty of one of the countless allegations.
# [{'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '799022225751871488', 'name': 'Donald Trump', 'description': '45th US President, Donald Trump'}}, {'domain': {'id': '35', 'name': 'Politician', 'description': 'Politicians in the world, like Joe Biden'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '35', 'name': 'Politician', 'description': 'Politicians in the world, like Joe Biden'}, 'entity': {'id': '799022225751871488', 'name': 'Donald Trump', 'description': '45th US President, Donald Trump'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '799022225751871488', 'name': 'Donald Trump', 'description': '45th US President, Donald Trump'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '847878884917886977', 'name': 'Politics', 'description': 'Politics'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1070032753834438656', 'name': 'Political figures', 'description': 'Politician'}}]
# @joncoopertweets Why hasn’t Griffin been arrested for Identity Theft?
# Why hasn’t Joseph Robinette Biden Jr been arrested for Graft by a public official?
# [{'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '1138106947234779137', 'name': 'Jon Cooper'}}, {'domain': {'id': '35', 'name': 'Politician', 'description': 'Politicians in the world, like Joe Biden'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '35', 'name': 'Politician', 'description': 'Politicians in the world, like Joe Biden'}, 'entity': {'id': '1138106947234779137', 'name': 'Jon Cooper'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '847878884917886977', 'name': 'Politics', 'description': 'Politics'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1070032753834438656', 'name': 'Political figures', 'description': 'Politician'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1138106947234779137', 'name': 'Jon Cooper'}}]
# @POTUS Yes, we do! You don't get to tell us what we can say period. Let's see now.. you can't even do that for yourself Joseph Robinette Biden Jr. others tell you what to say &amp; do 98% of the time.
# [{'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '35', 'name': 'Politician', 'description': 'Politicians in the world, like Joe Biden'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '847878884917886977', 'name': 'Politics', 'description': 'Politics'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1070032753834438656', 'name': 'Political figures', 'description': 'Politician'}}]
# @HillaryClinton WHY are these Democrat led counties/MAJOR cities making it SO much HARDER for Republicans to vote than Democrats?
# It’s (ALMOST) like this election isNOT supposed to to the FREE and FAIR election like the 2020 presidential election was for Mr. Joseph Robinette Biden Jr and 81 mill
# [{'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '35', 'name': 'Politician', 'description': 'Politicians in the world, like Joe Biden'}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '10040395078', 'name': 'Joe Biden', 'description': 'US President Joe Biden'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '847878884917886977', 'name': 'Politics', 'description': 'Politics'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1070032753834438656', 'name': 'Political figures', 'description': 'Politician'}}, {'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '10037721440', 'name': 'Hillary Clinton', 'description': 'Former First Lady of the United States Hillary Clinton'}}, {'domain': {'id': '35', 'name': 'Politician', 'description': 'Politicians in the world, like Joe Biden'}, 'entity': {'id': '10037721440', 'name': 'Hillary Clinton', 'description': 'Former First Lady of the United States Hillary Clinton'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '10037721440', 'name': 'Hillary Clinton', 'description': 'Former First Lady of the United States Hillary Clinton'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '847878884917886977', 'name': 'Politics', 'description': 'Politics'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1070032753834438656', 'name': 'Political figures', 'description': 'Politician'}}]

# %%
# Replace with your own search query
query = 'Joseph Robinette Biden Jr -is:retweet'

# Replace the limit=1000 with the maximum number of Tweets you want
for tweet in tweepy.Paginator(client.search_recent_tweets, query=query,
                              tweet_fields=['context_annotations', 'created_at'], max_results=100).flatten(limit=1000):
    print(tweet.id)
# Out:
# 1592062171994681344
# 1592015345518346240
# 1592012800268070912
# 1592011265156829184
# 1591979267562291200
# 1591970999586766848
# 1591956330994368513
# 1591945079471902722
# 1591930310689980417
# 1591925845463293952
# 1591922070619033601
# 1591909046596300800
# 1591908406834728970
# 1591880382139764737
# 1591873513979367424
# 1591871994601132037
# 1591860471505862656
# 1591833308547403776
# 1591723102916038657
# 1591698676329906176
# 1591685781407830016
# 1591681251068776450
# 1591666285389414401
# 1591647889218228226
# 1591634786241900544
# 1591628394239754240
# 1591616593100144641
# 1591599164299046913
# 1591594431358308354
# 1591591521987727360
# 1591576446992105476
# 1591532153283956736
# 1591531030762377217
# 1591520506213285891
# 1591453532892561410
# 1591411871533658112
# 1591289181191507971
# 1591238628839403520
# 1591238581095632896
# 1591231924898779137
# 1591206227031523329
# 1591158817081135104
# 1591122438309412867
# 1591120418399997952
# 1591101636360818690
# 1591096903978344448
# 1591090101186367488
# 1591067378775097344
# 1590987684457381888
# 1590929044643938304
# 1590909243695464449
# 1590905794815459329
# 1590876507723137030
# 1590869368749137920
# 1590865627316891650
# 1590848172016164864
# 1590807941133012992
# 1590729497287933952
# 1590725018019057664
# 1590643575834148865
# 1590550039528902657
# 1590541497518415873
# 1590534755300167680
# 1590510690972073986
# 1590503977837527040
# 1590503503750782976
# 1590477475045601280
# 1590473937518927873
# 1590469518844841984
# 1590450529419022336
# 1590447799497527296
# 1590441219200782337
# 1590424871041110017
# 1590406372990255104
# 1590405541821456384
# 1590392948298248194
# 1590380062867886080
# 1590371305622503430
# 1590350806129074176
# 1590350262748647424
# 1590333387436269569
# 1590320570276904964
# 1590254781549129728
# 1590233505316732930
# 1590231953491755008
# 1590222163260628992
# 1590200447234904064
# 1590188850714144769
# 1590188488494055424
# 1590187498730586112
# 1590170170051670017
# 1590159669099892737
# 1590149767749042179
# 1590141763217674240
# 1590134356693385216
# 1590127340423884800
# 1590069777019863040
# 1590058344034996224
# 1590057713366888448
# 1590032110030843904
# 1590030054750564352
# 1590022428176285696
# 1590016857750536192
# 1590011294559928321
# 1590002036820815872
# 1590000098708111360
# 1589973684365643776
# 1589955576695357440
# 1589853310965932033
# 1589837669957128193
# 1589803898524794881
# 1589782272445747206
# 1589782271053238274
# 1589706413341048832
# 1589691875258089472
# 1589679450266161153
# 1589667858174603264
# 1589655427297705985
# 1589654951432957952
# 1589624797054443521

# %%
# Create a text file to record tweets id about Joe Biden
query = 'Joseph Robinette Biden Jr -is:retweet'

# Name and path of the file where you want the Tweets written to
file_name = 'tweets.txt'

with open(file_name, 'a+') as filehandle:
    for tweet in tweepy.Paginator(client.search_recent_tweets, query=query,
                                  tweet_fields=['context_annotations', 'created_at'], max_results=100).flatten(
            limit=1000):
        filehandle.write('%s\n' % tweet.id)

# %%
# Display the profile images for each user 
query = 'Joseph Robinette Biden Jr -is:retweet'

tweets = client.search_recent_tweets(query=query, tweet_fields=['context_annotations', 'created_at'],
                                     user_fields=['profile_image_url'], expansions='author_id', max_results=100)

# Get users list from the includes object
users = {u["id"]: u for u in tweets.includes['users']}

for tweet in tweets.data:
    if users[tweet.author_id]:
        user = users[tweet.author_id]
        print(user.profile_image_url)
# Out:
# https://pbs.twimg.com/profile_images/1541130056529072128/rfQ__-Je_normal.jpg
# https://pbs.twimg.com/profile_images/1249961240010645504/lqqMKPyu_normal.png
# https://pbs.twimg.com/profile_images/1587451928514109440/9LzxCCYR_normal.jpg
# https://pbs.twimg.com/profile_images/1382836881818279937/o89p_MZd_normal.jpg
# https://pbs.twimg.com/profile_images/1424928761024327680/eBcY1IVQ_normal.jpg
# https://pbs.twimg.com/profile_images/1089244544498057216/2WDOL92D_normal.jpg
# https://pbs.twimg.com/profile_images/1327037774680231942/1gsBTD34_normal.jpg
# https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png
# https://pbs.twimg.com/profile_images/1322266438413922304/JZuM9ZSJ_normal.jpg
# https://pbs.twimg.com/profile_images/1399539439068581888/HoLDZnSX_normal.jpg
# https://pbs.twimg.com/profile_images/887297617012633601/YMNlKD_P_normal.jpg
# https://pbs.twimg.com/profile_images/1401687673723621376/UNTMIOzU_normal.jpg
# https://pbs.twimg.com/profile_images/1591300798381711360/rTQoXIjV_normal.jpg
# https://pbs.twimg.com/profile_images/1541130056529072128/rfQ__-Je_normal.jpg
# https://pbs.twimg.com/profile_images/1591461957302984706/Jt0AR8ay_normal.jpg
# https://pbs.twimg.com/profile_images/1499069355329527812/4WVzsoKQ_normal.jpg
# https://pbs.twimg.com/profile_images/1591952679932248065/tfv1dKKS_normal.jpg
# https://pbs.twimg.com/profile_images/974477812412239872/RFikHQoX_normal.jpg
# https://pbs.twimg.com/profile_images/1355994669604331525/gqv6emj9_normal.jpg
# https://pbs.twimg.com/profile_images/1146756634326241280/W5wnDQdw_normal.jpg
# https://pbs.twimg.com/profile_images/1451231744187846667/Jte-kxuT_normal.jpg
# https://pbs.twimg.com/profile_images/690949380/___normal.jpg
# https://pbs.twimg.com/profile_images/1503933614798614529/oOg--IVE_normal.jpg
# https://pbs.twimg.com/profile_images/1505038498285318144/2SrLHvab_normal.jpg
# https://pbs.twimg.com/profile_images/1581637956216954880/euQKrBKN_normal.jpg
# https://pbs.twimg.com/profile_images/1518713721375412227/2NVY4qy1_normal.jpg
# https://pbs.twimg.com/profile_images/1591220132185096193/x4k07qna_normal.jpg
# https://pbs.twimg.com/profile_images/867938275331366912/5avV-QUE_normal.jpg
# https://pbs.twimg.com/profile_images/1285937970369921024/70aZNOyk_normal.jpg
# https://pbs.twimg.com/profile_images/1533978352838660098/JxnV7MMR_normal.jpg
# https://pbs.twimg.com/profile_images/1591439015525376001/TTFwrpub_normal.jpg
# https://pbs.twimg.com/profile_images/1587871284410605569/7S5LBQF9_normal.jpg
# https://pbs.twimg.com/profile_images/1365059285873483779/9Yr5Pkxu_normal.jpg
# https://pbs.twimg.com/profile_images/1591671004023193601/lzQpoq6o_normal.jpg
# https://pbs.twimg.com/profile_images/1496703315131998213/g_xl9ztw_normal.jpg
# https://pbs.twimg.com/profile_images/1520763429669289984/iUTRC6Vn_normal.jpg
# https://pbs.twimg.com/profile_images/1521863824470683649/KY2i-Q9O_normal.jpg
# https://pbs.twimg.com/profile_images/1354451254785748998/WV9Pepv1_normal.jpg
# https://pbs.twimg.com/profile_images/1552300881756004353/q_RJyNSQ_normal.jpg
# https://pbs.twimg.com/profile_images/378800000004019914/ac95235ae57e4f009c0a9a40dc167462_normal.jpeg
# https://pbs.twimg.com/profile_images/1512091316381175811/7ve0GFpS_normal.jpg
# https://pbs.twimg.com/profile_images/1567124823968747520/3Q57oBEZ_normal.jpg
# https://pbs.twimg.com/profile_images/1590067572354842625/Slu5dtqP_normal.jpg
# https://pbs.twimg.com/profile_images/1586787741261598720/NH5-48jN_normal.jpg
# https://pbs.twimg.com/profile_images/976877112320774144/jBL4y6nt_normal.jpg
# https://pbs.twimg.com/profile_images/464454642923884544/iBSzmRy__normal.jpeg
# https://pbs.twimg.com/profile_images/1087529646621511680/3K0m4Wy1_normal.jpg
# https://pbs.twimg.com/profile_images/1582569909518848001/qVc4RQWI_normal.jpg
# https://pbs.twimg.com/profile_images/1590112379672481792/sH5oS2Sf_normal.jpg
# https://pbs.twimg.com/profile_images/1579892015340265473/gb2BZ1Bb_normal.jpg
# https://pbs.twimg.com/profile_images/1507850902073274369/VjasUiWD_normal.jpg
# https://pbs.twimg.com/profile_images/1496703315131998213/g_xl9ztw_normal.jpg
# https://pbs.twimg.com/profile_images/1584317247862046722/8f2yoFCb_normal.jpg
# https://pbs.twimg.com/profile_images/1587898695659536386/PjY3fZIR_normal.jpg
# https://pbs.twimg.com/profile_images/1456089378435080194/Mg7RaauF_normal.jpg
# https://pbs.twimg.com/profile_images/1567124823968747520/3Q57oBEZ_normal.jpg
# https://pbs.twimg.com/profile_images/1567124823968747520/3Q57oBEZ_normal.jpg
# https://pbs.twimg.com/profile_images/1590042783678595076/4IFwIPfO_normal.jpg
# https://pbs.twimg.com/profile_images/1586863002606772225/VS19pwU7_normal.jpg
# https://pbs.twimg.com/profile_images/1185200343552090112/2FYmACzI_normal.jpg
# https://pbs.twimg.com/profile_images/1591790861221863424/GE6OWWWl_normal.jpg
# https://pbs.twimg.com/profile_images/1087529646621511680/3K0m4Wy1_normal.jpg
# https://pbs.twimg.com/profile_images/1323388866779176961/NgdgCxUD_normal.jpg
# https://pbs.twimg.com/profile_images/1268243507052900352/O1zsRWA2_normal.jpg
# https://pbs.twimg.com/profile_images/1512091316381175811/7ve0GFpS_normal.jpg
# https://pbs.twimg.com/profile_images/1519422110061445120/qeIfxIzn_normal.jpg
# https://pbs.twimg.com/profile_images/1584889286817636354/AeIFMVFA_normal.jpg
# https://pbs.twimg.com/profile_images/1499467517789679623/9Vx5IMus_normal.jpg
# https://pbs.twimg.com/profile_images/1496179228815114240/86gpy4vy_normal.jpg
# https://pbs.twimg.com/profile_images/1082021628186308610/zhmX9MWS_normal.jpg
# https://pbs.twimg.com/profile_images/1399226787037696000/lKM2NRT__normal.jpg
# https://pbs.twimg.com/profile_images/1514409560672452608/qW6dLEH-_normal.jpg
# https://pbs.twimg.com/profile_images/1567124823968747520/3Q57oBEZ_normal.jpg
# https://pbs.twimg.com/profile_images/1486642782676602883/yhP0gJki_normal.jpg
# https://pbs.twimg.com/profile_images/1482457243559907336/hRHcrV2a_normal.jpg
# https://pbs.twimg.com/profile_images/1557554318244470784/2-HZITqz_normal.jpg
# https://pbs.twimg.com/profile_images/1514429984445648898/sJGCFl-i_normal.jpg
# https://pbs.twimg.com/profile_images/1337751623108603905/jzDgpcMR_normal.jpg
# https://pbs.twimg.com/profile_images/1556367789400662016/jG5AOCKp_normal.jpg
# https://pbs.twimg.com/profile_images/1177985328658952194/3_GIqhQQ_normal.jpg
# https://pbs.twimg.com/profile_images/1557554318244470784/2-HZITqz_normal.jpg
# https://pbs.twimg.com/profile_images/1548069809899720704/trQjfgE5_normal.jpg
# https://pbs.twimg.com/profile_images/1581401487061782529/OaptqZL8_normal.jpg
# https://pbs.twimg.com/profile_images/1340904319617560578/1KcBKP7Q_normal.jpg
# https://pbs.twimg.com/profile_images/1445217194242191362/XIScWQsl_normal.jpg
# https://pbs.twimg.com/profile_images/1234702186195685377/dQ__gdc6_normal.jpg
# https://pbs.twimg.com/profile_images/1543979109566611459/uLkVJu2x_normal.jpg
# https://pbs.twimg.com/profile_images/1110226116512350210/bS9IET70_normal.jpg
# https://pbs.twimg.com/profile_images/1041545148079910912/pdLMQoS2_normal.jpg
# https://pbs.twimg.com/profile_images/1041545148079910912/pdLMQoS2_normal.jpg
# https://pbs.twimg.com/profile_images/1555033758545354757/d12qHAHy_normal.jpg
# https://pbs.twimg.com/profile_images/1588990416346652674/BCLODxBT_normal.jpg
# https://pbs.twimg.com/profile_images/1348756484050604035/5kEiOkiY_normal.jpg
# https://pbs.twimg.com/profile_images/1589870613744582657/26iKkDu5_normal.jpg
# https://pbs.twimg.com/profile_images/1529171785664430081/ExU68NXr_normal.jpg
# https://pbs.twimg.com/profile_images/1590042783678595076/4IFwIPfO_normal.jpg
# https://pbs.twimg.com/profile_images/1592092929962614784/4BrV_MSo_normal.jpg
# https://pbs.twimg.com/profile_images/1348756484050604035/5kEiOkiY_normal.jpg
# https://pbs.twimg.com/profile_images/1526699364353200135/tyl50aRb_normal.jpg
# https://pbs.twimg.com/profile_images/1590112379672481792/sH5oS2Sf_normal.jpg

# %% [markdown]
# # **Twitter Sentiment Analysis through Data Mining**

# %%
# Import and load required librairies and dependencies
import re 

import numpy as np

import tweepy 

from tweepy import OAuthHandler 

from textblob import TextBlob 

import matplotlib.pyplot as plt

import pandas as pd

from wordcloud import WordCloud

from better_profanity import profanity

# %%
your_query = input("Please enter your topic / person of interest: ")
your_query = "Joseph Robinette Biden Jr"
query = your_query + ' -is:retweet'
# get tweets from the API
tweets = client.search_recent_tweets(query=query,
                                     tweet_fields = ["created_at", "text", "source"],
                                     user_fields = ["name", "username", "location", "verified", "description"],
                                     max_results = 100,
                                     expansions='author_id'
                                     )
# Out:
# Please enter your topic / person of interest: Joseph Robinette Biden Jr

# %%
# import the pandas library
import pandas as pd
# create a list of records
tweet_info_ls = []
# iterate over each tweet and corresponding user details
for tweet, user in zip(tweets.data, tweets.includes['users']):
    tweet_info = {
        'created_at': tweet.created_at,
        'text': tweet.text,
        'source': tweet.source,
        'name': user.name,
        'username': user.username,
        'location': user.location,
        'verified': user.verified,
        'description': user.description
    }
    tweet_info_ls.append(tweet_info)
# create dataframe from the extracted records
tweets_df = pd.DataFrame(tweet_info_ls)
# display the dataframe
tweets_df.head()
# Out:
#                  created_at  \
# 0 2022-11-14 07:49:35+00:00
# 1 2022-11-14 04:43:31+00:00
# 2 2022-11-14 04:33:24+00:00
# 3 2022-11-14 04:27:18+00:00
# 4 2022-11-14 02:20:09+00:00
#
#                                                 text               source  \
# 0  Joseph Robinette Biden Jr. (born November 20, ...  Twitter for Android
# 1  @trumwill @CJohnsonYCCD I would say my only st...      Twitter Web App
# 2  Joseph Robinette Biden Jr https://t.co/URcdzeOv0X      Twitter Web App
# 3  @BeschlossDC You’re a fraud of epic proportion...   Twitter for iPhone
# 4  Folks, Joseph Robinette Biden Jr knows what he...   Twitter for iPhone
#
#                  name        username                      location  verified  \
# 0        Shane Hurley  ShaneHurley911                          None     False
# 1  A.D. \Mikkhi/ Sixx      adfoozsixx                  Molden Heath     False
# 2      Rosedark ☭ 🇵🇸📕    FreeRosedark           He/She/It/Void/Vamp     False
# 3              OnTime    breakingplow                The Deep South     False
# 4      ⚽️iam_United⚽️       GilliannW  Lost in America....literally     False
#
#                                          description
# 0
# 1  Rawr Matari! HighSec Scrub, LowSec Pirate in T...
# 2  Marxist Leninist Maoist and Golden Wind enjoye...
# 3                                  Live and learn...
# 4  ⓘ This user hopes you never give up. Devout Ca...

# %%
# import the pandas library
import pandas as pd
# create a list of records
tweet_info_ls = []
# iterate over each tweet and corresponding user details
for tweet, user in zip(tweets.data, tweets.includes['users']):
    tweet_info = {
        'text': tweet.text,
        'username': user.username,
        'location': user.location,
    }
    tweet_info_ls.append(tweet_info)
# create dataframe from the extracted records
tweets_df = pd.DataFrame(tweet_info_ls)
# display the dataframe
tweets_df.head()
# Out:
#                                                 text        username  \
# 0  Joseph Robinette Biden Jr. (born November 20, ...  ShaneHurley911
# 1  @trumwill @CJohnsonYCCD I would say my only st...      adfoozsixx
# 2  Joseph Robinette Biden Jr https://t.co/URcdzeOv0X    FreeRosedark
# 3  @BeschlossDC You’re a fraud of epic proportion...    breakingplow
# 4  Folks, Joseph Robinette Biden Jr knows what he...       GilliannW
#
#                        location
# 0                          None
# 1                  Molden Heath
# 2           He/She/It/Void/Vamp
# 3                The Deep South
# 4  Lost in America....literally

# %%
tweets_df.shape
# Out:
# (88, 3)

# %%
# Create a function to clean the tweets. Remove profanity, unnecessary characters, spaces, and stopwords.

def clean_tweet(tweet):
    if type(tweet) == np.float:
        return ""
    r = tweet.lower()
    r = profanity.censor(r)
    r = re.sub("'", "", r) # This is to avoid removing contractions in english
    r = re.sub("@[A-Za-z0-9_]+","", r)
    r = re.sub("#[A-Za-z0-9_]+","", r)
    r = re.sub(r'http\S+', '', r)
    r = re.sub('[()!?]', ' ', r)
    r = re.sub('\[.*?\]',' ', r)
    r = re.sub("[^a-z0-9]"," ", r)
    r = r.split()
    stopwords = ["for", "on", "an", "a", "of", "and", "in", "the", "to", "from"]
    r = [w for w in r if not w in stopwords]
    r = " ".join(word for word in r)
    return r

# %%
tweets_df.iloc[0,0]
# Out:
# 'Joseph Robinette Biden Jr.\xa0(born November 20, 1942), an American politician who is the 46th and current\xa0president of the United States.'

# %%
tweets_df["text"].iloc[0]
# Out:
# 'Joseph Robinette Biden Jr.\xa0(born November 20, 1942), an American politician who is the 46th and current\xa0president of the United States.'

# %%
tweet_list = tweets_df.text.to_list()

# %%
cleaned = [clean_tweet(tw) for tw in tweet_list]
cleaned
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   after removing the cwd from sys.path.
# ['joseph robinette biden jr born november 20 1942 american politician who is 46th current president united states',
#  'i would say my only strong opinion joseph robinette biden jr is hes never met hot mic he didnt like',
#  'joseph robinette biden jr',
#  'you re fraud epic proportions you vastly overstate situation biggest threats democracy are things like our moral social decline staggering national debt corrupt political lifers like joseph robinette biden jr',
#  'folks joseph robinette biden jr knows what he s doing i stand with all way second term don t care if he s as old as noah',
#  'thank you president joseph robinette biden jr',
#  'our planet thus humankind are far better off because joseph robinette biden jr how many people throughout history can such statement be made',
#  'there s never been more openly thanks hunter corrupt politician than joseph robinette biden jr',
#  'im vote d or democracy is at risk democrat even i dont have strong opinions joseph robinette biden jr',
#  'everyone expect joseph robinette biden jr',
#  'i supported him primary general im hardly normie but even i dont have strong opinions joseph robinette biden jr',
#  'u s has pretty great leader right now joseph robinette biden jr midterm results it seems like lot people feel way i do',
#  'joseph robinette biden jr',
#  'joseph robinette biden jr born november 20 1942 46th current president united states donald john trump born june 14 1946 45th president united states january 20 2017 january 20 2021',
#  'joseph robinette biden jr comrade',
#  'yall doubted now potus joseph robinette biden jr august 11 2020 too',
#  'joseph robinette biden jr couramment appel joe biden d o ba d n n le 20 novembre 1942 scranton pennsylvanie est un homme d tat am ricain 47e vice pr sident des tats unis de 2009 2017 il est le 46e pr sident des tats unis depuis 2021 gt 80 years gt 65 y',
#  'a1 merrick brian garland a2 joseph robinette biden jr q3 why hasnt merrick garland indicted trump a3 joseph robinette biden jr biden is smoother liar but hes actually governing far right drumpf which is why wall street installed him',
#  'sorry may be best many generations his name is joseph robinette biden jr unlike you he does not smoke donald trumps pole as you do',
#  'joseph robinette biden jr all his fullness may guide you like it has all your life',
#  'oh my he must take his bed with vapors whatever shall joseph robinette biden jr do',
#  'joseph robinette biden jr',
#  'mcshitface will not be stealing any court seats president joseph robinette biden jr we got blue wall senate now lets keep georgia too',
#  'this is not encouraging democrats 2024 but also if weve learned one thing you cannot count out joseph robinette biden jr',
#  'nothing about that lying con man is good ask ukraine about what biden obama did their peaceful country ask afghanistan biden is all about cartels money laundering drug money dead baby money senator joseph robinette biden jr is hateful racist thief',
#  'while haters are busy screaming too old after lifetime trials tribulations it just might be that joseph robinette biden jr is actually hitting his stride right here eve his 80th birthday',
#  'catherine cortez masto s phone is currently lighting up with call joseph robinette biden jr',
#  'actually she got top forgiveness line i heard got her debt erased by his magnificence one best presidents us history joseph robinette biden jr',
#  'assuming anyone normal has strong opinions about joseph robinette biden jr was obvious mistake jump',
#  'bless joseph robinette biden jr retweet if you agree',
#  'by joseph robinette biden jr himself',
#  'olivia by 2024 joseph robinette biden jr will be placed house arrest treason due his mental illness will continue believe he is still senator',
#  'yes desantis definitely lacks powerful charisma alpha male joseph robinette biden jr',
#  'trump united states 24 search joseph robinette biden jrs house confiscate his property',
#  'never underestimate joseph robinette biden jr never do that',
#  'president joseph robinette biden jr has not always been right side just like every human being that ever lived but he has been most significant president since president abraham lincoln',
#  'you kick joseph robinette biden jr',
#  'i m inspired by wordsmith himself joseph robinette biden jr when i say i have two words you you are breaker curfews',
#  'those are all literally quotes joseph robinette biden jr',
#  'joseph robinette biden jr',
#  'joseph robinette biden jr asep bidin abidin show off diatas langit bali sekaligus mudik karena bali adalah sunda kecil',
#  'veterans day america pos president joseph robinette biden jr is overseas at useless climate conference giving billions our dollars away hoax',
#  'due u recall when senator unleashed concept statement circa november 3rd at mission at joseph robinette biden jr was nicest guy youd wanna meet',
#  'that joseph robinette biden jr is complete',
#  'these three are behind all chaos going such as amp wanting change electric cars etc donald john trump sr michael richard pence joseph robinette biden jr chaos 222 155 243 46 666',
#  'spin publishing president joseph robinette biden jr presents remarks at 27th conference parties un framework convention climate change cop27 convened sharm el sheik egypt reported by karen ann carr',
#  'presidents iq john quincy adams genus 175 iq joseph robinette biden jr genus iq 169 thomas jefferson iq 160 james madison iq 160 jfk iq 160 bill clinton iq 159 barack hussein obama ii iq 158 jimmy carter iq 157 abraham lincoln iq 150 donald john trump not genus iq 89',
#  'all ik is that joseph robinette biden jr owe me 20k',
#  'mr joseph robinette biden jr i don t even know your pronouns sir i realize that you have used your executive branch order magic wand create other 56 genders your administration is bent create 2022',
#  'joseph robinette biden jr',
#  'joseph robinette joe biden jr 2',
#  'if theres one thing learn these historic midterms then its this never underestimate joseph robinette biden jr',
#  'do you know how bad you have as party take midterm l joseph robinette biden jr',
#  'i love president joseph robinette biden jr he delivers tells truth unlike you stop tweeting go work do your own job marsha',
#  'balance due these loans is between joseph robinette biden jr it s above me now',
#  'gop neutered lame duck prez joseph robinette biden jr now go get your shine box',
#  'holy chit joseph robinette biden jr just broke into screaming ebonics live tv kamalas right cheek is caving',
#  'yo he venido diciendo en los ltimos meses que el presidente vladimir vlad mirovich putin y el presidente joseph robinette biden jr deben sentarse firmar los acuerdos de paz que se tengan que firmar',
#  'everyone remember joseph robinette biden jr its my exam today',
#  'joseph robinette biden jr est un homme d tat am ricain 47e vice pr sident des tats unis de 2009 2017 il est le 46e pr sident des tats unis depuis 2021 wikipedia le turn over depuis deux ans est plus rapide quau 10 downing street',
#  'dear joseph robinette biden jr i speak all americans ukrainian when i say that we need ww3 kids these days are too soft always whine smallest things if us doesnt invade russia then im no longer american citizen comon usa',
#  'presidents iq john quincy adams genus 175 iq joseph robinette biden jr genus iq 169 thomas jefferson iq 160 james madison iq 160 jfk iq 160 bill clinton iq 159 barack hussein obama ii iq 158 jimmy carter iq 157 abraham lincoln iq 150 donald john trump not genus iq 89',
#  'joseph robinette biden jr just doesnt lose',
#  'talk yo joseph robinette biden jr',
#  'sing inget ka purwadksi bisi cilaka balukarna loba jalma sabenerna karuhuna urang lembur sunda besar high lander conto itungana tina arana joseph asep robinette biden jr mikhail sergeyevich gorbachev cecep asep gorbacep recep tayyip erdo encep kasep asep',
#  'joseph robinette bidens ppl owned slaves',
#  'joseph robinette biden jr is only president who could get us through times we re living right now',
#  'joseph robinette biden jr',
#  'thee comeback kid primaries general election original ga runoff infrastructure bill inflation reduction act american rescue plan chips amp science act pact act judicial nominations midterm success all deemed impossible but yet joseph robinette biden jr did it all',
#  'so you know when president joseph robinette biden jr gave that speech about democracy being at stake how all pundits said it was dumb because people didnt care about that uncle joe was right again',
#  'joseph robinette biden jr hatte viel zu gratulieren',
#  'y all keep underestimating president joseph robinette biden jr',
#  'joseph robinette biden jr is now official lame duck 2 years',
#  'i couldnt tell you who were last republican president say he represents all americans but i can tell you last democratic president say it hes president joseph robinette biden jr',
#  'reminder that america nigeria will be commemorating celebrating two very important 80th birthdays weeks ahead joseph robinette biden jr november 20 muhammadu buhari december 17 aso ebi details will be announced due course',
#  'joseph robinette biden jr is american politician who is 46th current president united states member democratic party he previously served as 47th vice president 2009 2017 under president barack obama represented delaware us',
#  'joseph robinette biden jr',
#  'president joseph robinette biden jr masterclass midterms politics',
#  'i feel like it can be argued that no one has been more successful failing up than joseph robinette biden jr',
#  'i shall not vote us election until given permission by president joseph robinette biden jr gives me permission',
#  'joseph robinette biden jr is american politician who is 46th current president united states member democratic party he previously served as 47th vice president 2009 2017 under president barack obama represented delaware us',
#  'as ever literal dumbest thing you can do is underestimate joseph robinette biden jr',
#  'joseph robinette biden jr one most successful politicians us history underestimate man at your peril',
#  'joseph robinette biden jr amp donald john trump together they planned division power white house there will be no winners or losers presidential duel only one be defeated is american people',
#  'it s good night be president joseph robinette biden jr',
#  'did joseph robinette biden jr just have best democratic midterm since fdr',
#  'joseph robinette biden jr runs election 2024 beating trump again thus becoming 2 term president',
#  'joseph robinette joe biden jr']

# %%
# Define the sentiment objects using TextBlob

sentiment_objects = [TextBlob(tweet) for tweet in cleaned]

sentiment_objects[0].polarity, sentiment_objects[0]
# Out:
# (0.0,
#  TextBlob("joseph robinette biden jr born november 20 1942 american politician who is 46th current president united states"))

# %%
# Create a list of polarity values and tweet text

sentiment_values = [[tweet.sentiment.polarity, str(tweet)] for tweet in sentiment_objects]

# Print the value of the 0th row.

sentiment_values[0]
# Print all the sentiment values

sentiment_values[0:99]
# Out:
# [[0.0,
#   'joseph robinette biden jr born november 20 1942 american politician who is 46th current president united states'],
#  [0.22777777777777777,
#   'i would say my only strong opinion joseph robinette biden jr is hes never met hot mic he didnt like'],
#  [0.0, 'joseph robinette biden jr'],
#  [-0.061111111111111116,
#   'you re fraud epic proportions you vastly overstate situation biggest threats democracy are things like our moral social decline staggering national debt corrupt political lifers like joseph robinette biden jr'],
#  [0.05,
#   'folks joseph robinette biden jr knows what he s doing i stand with all way second term don t care if he s as old as noah'],
#  [0.0, 'thank you president joseph robinette biden jr'],
#  [0.275,
#   'our planet thus humankind are far better off because joseph robinette biden jr how many people throughout history can such statement be made'],
#  [0.06666666666666665,
#   'there s never been more openly thanks hunter corrupt politician than joseph robinette biden jr'],
#  [0.4333333333333333,
#   'im vote d or democracy is at risk democrat even i dont have strong opinions joseph robinette biden jr'],
#  [0.0, 'everyone expect joseph robinette biden jr'],
#  [0.14791666666666667,
#   'i supported him primary general im hardly normie but even i dont have strong opinions joseph robinette biden jr'],
#  [0.44523809523809527,
#   'u s has pretty great leader right now joseph robinette biden jr midterm results it seems like lot people feel way i do'],
#  [0.0, 'joseph robinette biden jr'],
#  [0.0,
#   'joseph robinette biden jr born november 20 1942 46th current president united states donald john trump born june 14 1946 45th president united states january 20 2017 january 20 2021'],
#  [0.0, 'joseph robinette biden jr comrade'],
#  [0.0, 'yall doubted now potus joseph robinette biden jr august 11 2020 too'],
#  [0.0,
#   'joseph robinette biden jr couramment appel joe biden d o ba d n n le 20 novembre 1942 scranton pennsylvanie est un homme d tat am ricain 47e vice pr sident des tats unis de 2009 2017 il est le 46e pr sident des tats unis depuis 2021 gt 80 years gt 65 y'],
#  [0.12857142857142856,
#   'a1 merrick brian garland a2 joseph robinette biden jr q3 why hasnt merrick garland indicted trump a3 joseph robinette biden jr biden is smoother liar but hes actually governing far right drumpf which is why wall street installed him'],
#  [0.3333333333333333,
#   'sorry may be best many generations his name is joseph robinette biden jr unlike you he does not smoke donald trumps pole as you do'],
#  [0.0,
#   'joseph robinette biden jr all his fullness may guide you like it has all your life'],
#  [0.0,
#   'oh my he must take his bed with vapors whatever shall joseph robinette biden jr do'],
#  [0.0, 'joseph robinette biden jr'],
#  [0.0,
#   'mcshitface will not be stealing any court seats president joseph robinette biden jr we got blue wall senate now lets keep georgia too'],
#  [0.0,
#   'this is not encouraging democrats 2024 but also if weve learned one thing you cannot count out joseph robinette biden jr'],
#  [0.25,
#   'nothing about that lying con man is good ask ukraine about what biden obama did their peaceful country ask afghanistan biden is all about cartels money laundering drug money dead baby money senator joseph robinette biden jr is hateful racist thief'],
#  [0.12142857142857143,
#   'while haters are busy screaming too old after lifetime trials tribulations it just might be that joseph robinette biden jr is actually hitting his stride right here eve his 80th birthday'],
#  [0.0,
#   'catherine cortez masto s phone is currently lighting up with call joseph robinette biden jr'],
#  [0.5,
#   'actually she got top forgiveness line i heard got her debt erased by his magnificence one best presidents us history joseph robinette biden jr'],
#  [0.19444444444444442,
#   'assuming anyone normal has strong opinions about joseph robinette biden jr was obvious mistake jump'],
#  [0.0, 'bless joseph robinette biden jr retweet if you agree'],
#  [0.0, 'by joseph robinette biden jr himself'],
#  [-0.09166666666666667,
#   'olivia by 2024 joseph robinette biden jr will be placed house arrest treason due his mental illness will continue believe he is still senator'],
#  [0.09999999999999999,
#   'yes desantis definitely lacks powerful charisma alpha male joseph robinette biden jr'],
#  [0.0,
#   'trump united states 24 search joseph robinette biden jrs house confiscate his property'],
#  [0.0, 'never underestimate joseph robinette biden jr never do that'],
#  [0.2901785714285714,
#   'president joseph robinette biden jr has not always been right side just like every human being that ever lived but he has been most significant president since president abraham lincoln'],
#  [0.0, 'you kick joseph robinette biden jr'],
#  [0.0,
#   'i m inspired by wordsmith himself joseph robinette biden jr when i say i have two words you you are breaker curfews'],
#  [0.0, 'those are all literally quotes joseph robinette biden jr'],
#  [0.0, 'joseph robinette biden jr'],
#  [0.0,
#   'joseph robinette biden jr asep bidin abidin show off diatas langit bali sekaligus mudik karena bali adalah sunda kecil'],
#  [-0.5,
#   'veterans day america pos president joseph robinette biden jr is overseas at useless climate conference giving billions our dollars away hoax'],
#  [-0.0625,
#   'due u recall when senator unleashed concept statement circa november 3rd at mission at joseph robinette biden jr was nicest guy youd wanna meet'],
#  [0.1, 'that joseph robinette biden jr is complete'],
#  [-0.2,
#   'these three are behind all chaos going such as amp wanting change electric cars etc donald john trump sr michael richard pence joseph robinette biden jr chaos 222 155 243 46 666'],
#  [0.0,
#   'spin publishing president joseph robinette biden jr presents remarks at 27th conference parties un framework convention climate change cop27 convened sharm el sheik egypt reported by karen ann carr'],
#  [0.0,
#   'presidents iq john quincy adams genus 175 iq joseph robinette biden jr genus iq 169 thomas jefferson iq 160 james madison iq 160 jfk iq 160 bill clinton iq 159 barack hussein obama ii iq 158 jimmy carter iq 157 abraham lincoln iq 150 donald john trump not genus iq 89'],
#  [0.0, 'all ik is that joseph robinette biden jr owe me 20k'],
#  [0.1875,
#   'mr joseph robinette biden jr i don t even know your pronouns sir i realize that you have used your executive branch order magic wand create other 56 genders your administration is bent create 2022'],
#  [0.0, 'joseph robinette biden jr'],
#  [0.0, 'joseph robinette joe biden jr 2'],
#  [0.0,
#   'if theres one thing learn these historic midterms then its this never underestimate joseph robinette biden jr'],
#  [-0.6999999999999998,
#   'do you know how bad you have as party take midterm l joseph robinette biden jr'],
#  [0.55,
#   'i love president joseph robinette biden jr he delivers tells truth unlike you stop tweeting go work do your own job marsha'],
#  [-0.0625,
#   'balance due these loans is between joseph robinette biden jr it s above me now'],
#  [-0.5,
#   'gop neutered lame duck prez joseph robinette biden jr now go get your shine box'],
#  [0.21103896103896103,
#   'holy chit joseph robinette biden jr just broke into screaming ebonics live tv kamalas right cheek is caving'],
#  [0.0,
#   'yo he venido diciendo en los ltimos meses que el presidente vladimir vlad mirovich putin y el presidente joseph robinette biden jr deben sentarse firmar los acuerdos de paz que se tengan que firmar'],
#  [0.0, 'everyone remember joseph robinette biden jr its my exam today'],
#  [0.0,
#   'joseph robinette biden jr est un homme d tat am ricain 47e vice pr sident des tats unis de 2009 2017 il est le 46e pr sident des tats unis depuis 2021 wikipedia le turn over depuis deux ans est plus rapide quau 10 downing street'],
#  [0.05,
#   'dear joseph robinette biden jr i speak all americans ukrainian when i say that we need ww3 kids these days are too soft always whine smallest things if us doesnt invade russia then im no longer american citizen comon usa'],
#  [0.0,
#   'presidents iq john quincy adams genus 175 iq joseph robinette biden jr genus iq 169 thomas jefferson iq 160 james madison iq 160 jfk iq 160 bill clinton iq 159 barack hussein obama ii iq 158 jimmy carter iq 157 abraham lincoln iq 150 donald john trump not genus iq 89'],
#  [0.0, 'joseph robinette biden jr just doesnt lose'],
#  [0.0, 'talk yo joseph robinette biden jr'],
#  [0.16,
#   'sing inget ka purwadksi bisi cilaka balukarna loba jalma sabenerna karuhuna urang lembur sunda besar high lander conto itungana tina arana joseph asep robinette biden jr mikhail sergeyevich gorbachev cecep asep gorbacep recep tayyip erdo encep kasep asep'],
#  [0.0, 'joseph robinette bidens ppl owned slaves'],
#  [0.14285714285714285,
#   'joseph robinette biden jr is only president who could get us through times we re living right now'],
#  [0.0, 'joseph robinette biden jr'],
#  [0.011666666666666691,
#   'thee comeback kid primaries general election original ga runoff infrastructure bill inflation reduction act american rescue plan chips amp science act pact act judicial nominations midterm success all deemed impossible but yet joseph robinette biden jr did it all'],
#  [-0.04464285714285715,
#   'so you know when president joseph robinette biden jr gave that speech about democracy being at stake how all pundits said it was dumb because people didnt care about that uncle joe was right again'],
#  [0.0, 'joseph robinette biden jr hatte viel zu gratulieren'],
#  [0.0, 'y all keep underestimating president joseph robinette biden jr'],
#  [-0.5, 'joseph robinette biden jr is now official lame duck 2 years'],
#  [0.0,
#   'i couldnt tell you who were last republican president say he represents all americans but i can tell you last democratic president say it hes president joseph robinette biden jr'],
#  [0.1975,
#   'reminder that america nigeria will be commemorating celebrating two very important 80th birthdays weeks ahead joseph robinette biden jr november 20 muhammadu buhari december 17 aso ebi details will be announced due course'],
#  [-0.05555555555555555,
#   'joseph robinette biden jr is american politician who is 46th current president united states member democratic party he previously served as 47th vice president 2009 2017 under president barack obama represented delaware us'],
#  [0.0, 'joseph robinette biden jr'],
#  [0.0, 'president joseph robinette biden jr masterclass midterms politics'],
#  [0.625,
#   'i feel like it can be argued that no one has been more successful failing up than joseph robinette biden jr'],
#  [0.0,
#   'i shall not vote us election until given permission by president joseph robinette biden jr gives me permission'],
#  [-0.05555555555555555,
#   'joseph robinette biden jr is american politician who is 46th current president united states member democratic party he previously served as 47th vice president 2009 2017 under president barack obama represented delaware us'],
#  [0.0,
#   'as ever literal dumbest thing you can do is underestimate joseph robinette biden jr'],
#  [0.625,
#   'joseph robinette biden jr one most successful politicians us history underestimate man at your peril'],
#  [-0.05,
#   'joseph robinette biden jr amp donald john trump together they planned division power white house there will be no winners or losers presidential duel only one be defeated is american people'],
#  [0.7, 'it s good night be president joseph robinette biden jr'],
#  [1.0,
#   'did joseph robinette biden jr just have best democratic midterm since fdr'],
#  [0.45,
#   'joseph robinette biden jr runs election 2024 beating trump again thus becoming 2 term president'],
#  [0.0, 'joseph robinette joe biden jr']]

# %%
# Create a dataframe of each tweet against its polarity

sentiment_df = pd.DataFrame(sentiment_values, columns=["polarity", "tweet"])

sentiment_df
# Out:
#     polarity                                              tweet
# 0   0.000000  joseph robinette biden jr born november 20 194...
# 1   0.227778  i would say my only strong opinion joseph robi...
# 2   0.000000                          joseph robinette biden jr
# 3  -0.061111  you re fraud epic proportions you vastly overs...
# 4   0.050000  folks joseph robinette biden jr knows what he ...
# ..       ...                                                ...
# 83 -0.050000  joseph robinette biden jr amp donald john trum...
# 84  0.700000  it s good night be president joseph robinette ...
# 85  1.000000  did joseph robinette biden jr just have best d...
# 86  0.450000  joseph robinette biden jr runs election 2024 b...
# 87  0.000000                      joseph robinette joe biden jr
#
# [88 rows x 2 columns]

# %%
# Save the polarity column as 'n'.

n=sentiment_df["polarity"]

# Convert this column into a series, 'm'. 

m=pd.Series(n)

m
# Out:
# 0     0.000000
# 1     0.227778
# 2     0.000000
# 3    -0.061111
# 4     0.050000
#         ...
# 83   -0.050000
# 84    0.700000
# 85    1.000000
# 86    0.450000
# 87    0.000000
# Name: polarity, Length: 88, dtype: float64

# %%
# Initialize variables, 'pos', 'neg', 'neu'.

pos=0
neg=0
neu=0

# Create a loop to classify the tweets as Positive, Negative, or Neutral.
# Count the number of each.

for items in m:
    if items>0:
        print("Positive")
        pos=pos+1
    elif items<0:
        print("Negative")
        neg=neg+1
    else:
        print("Neutral")
        neu=neu+1
        
print(pos,neg,neu)
# Out:
# Neutral
# Positive
# Neutral
# Negative
# Positive
# Neutral
# Positive
# Positive
# Positive
# Neutral
# Positive
# Positive
# Neutral
# Neutral
# Neutral
# Neutral
# Neutral
# Positive
# Positive
# Neutral
# Neutral
# Neutral
# Neutral
# Neutral
# Positive
# Positive
# Neutral
# Positive
# Positive
# Neutral
# Neutral
# Negative
# Positive
# Neutral
# Neutral
# Positive
# Neutral
# Neutral
# Neutral
# Neutral
# Neutral
# Negative
# Negative
# Positive
# Negative
# Neutral
# Neutral
# Neutral
# Positive
# Neutral
# Neutral
# Neutral
# Negative
# Positive
# Negative
# Negative
# Positive
# Neutral
# Neutral
# Neutral
# Positive
# Neutral
# Neutral
# Neutral
# Positive
# Neutral
# Positive
# Neutral
# Positive
# Negative
# Neutral
# Neutral
# Negative
# Neutral
# Positive
# Negative
# Neutral
# Neutral
# Positive
# Neutral
# Negative
# Neutral
# Positive
# Negative
# Positive
# Positive
# Positive
# Neutral
# 29 13 46

# %%
# Create a pie chart with the polarity answers
pieLabels=["Positive","Negative","Neutral"]

populationShare=[pos,neg,neu]

figureObject, axesObject = plt.subplots()

axesObject.pie(populationShare,labels=pieLabels,autopct='%1.2f',startangle=90)

axesObject.axis('equal')

plt.show()

# %% [markdown]
#  1. Almost 53% of the tweets are neutral sentiment about Joseph Robinette Biden Jr , whatever the subject is.
#  2. 32.95% are positive sentiment, and 14.77% are negative sentiment.

# %%
# Display the number of twitter users who feel a certain way about the given topic.

print("%f percent of twitter users feel positive about %s"%(pos,query))

print("%f percent of twitter users feel negative about %s"%(neg,query))

print("%f percent of twitter users feel neutral about %s"%(neu,query))
# Out:
# 29.000000 percent of twitter users feel positive about Joseph Robinette Biden Jr -is:retweet
# 13.000000 percent of twitter users feel negative about Joseph Robinette Biden Jr -is:retweet
# 46.000000 percent of twitter users feel neutral about Joseph Robinette Biden Jr -is:retweet

# %%
# Create a Wordcloud from the tweets

all_words = ' '.join([text for text in cleaned])
wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(all_words)

plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %% [markdown]
# # Sentiment Analysis (through Scraping) - Data Mining

# %%
# Import and load required librairies and dependencies
# !pip install snscrape
from datetime import date
import snscrape.modules.twitter as sntwitter
import pandas as pd
import numpy as np
from textblob import TextBlob
from wordcloud import WordCloud
import re
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
import nltk
from nltk.stem.snowball import SnowballStemmer
from nltk.corpus import stopwords
import spacy
nlp = spacy.load("en_core_web_sm")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting snscrape
#   Downloading snscrape-0.3.4-py3-none-any.whl (35 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from snscrape) (4.9.1)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.7/dist-packages (from snscrape) (2.23.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from snscrape) (4.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->snscrape) (2022.9.24)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->snscrape) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->snscrape) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->snscrape) (2.10)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->snscrape) (1.7.1)
# Installing collected packages: snscrape
# Successfully installed snscrape-0.3.4

# %%
tweets_list = []
maxTweets = 1000
# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('Joseph Robinette Biden').get_items()):
    if i>maxTweets:
        break
    tweets_list.append([tweet.content])
    
# Creating a dataframe from the tweets list above
tweets_to_df = pd.DataFrame(tweets_list, columns=['Tweets'])
tweets_to_df.shape
# Out:
# (1001, 1)

# %%
tweets_to_df.head() #lists first five tweets
# Out:
#                                               Tweets
# 0  @GlenninVirginia @George11z11 @WYtrades @still...
# 1  @daveweigel michael shannon as freddie mercury...
# 2  Presidents, "IQ"\n\nJohn Quincy Adams GENUS 17...
# 3  @PopeJohn666666 @Graywolf73 @stock_janine @LPN...
# 4  @Alleswelling @KamVTV @ScottPresler @pnjaban S...

# %%
#clean the tweets with a function
def cleanTweets(text):
    text = re.sub('@[A-Za-z0-9_]+', '', text) #removes @mentions
    text = re.sub('#','',text) #removes hastag '#' symbol
    text = re.sub('RT[\s]+','',text)
    text = re.sub('https?:\/\/\S+', '', text) 
    text = re.sub('\n',' ',text)
    return text
tweets_to_df['cleanedTweets'] = tweets_to_df['Tweets'].apply(cleanTweets) #apply cleanTweet function to the tweet
tweets_to_df.head() #compares original tweets with cleaned Tweets
# Out:
#                                               Tweets  \
# 0  @GlenninVirginia @George11z11 @WYtrades @still...
# 1  @daveweigel michael shannon as freddie mercury...
# 2  Presidents, "IQ"\n\nJohn Quincy Adams GENUS 17...
# 3  @PopeJohn666666 @Graywolf73 @stock_janine @LPN...
# 4  @Alleswelling @KamVTV @ScottPresler @pnjaban S...
#
#                                        cleanedTweets
# 0                                    Evil never dies
# 1   michael shannon as freddie mercury. michael s...
# 2  Presidents, "IQ"  John Quincy Adams GENUS 175-...
# 3                                     Sure they did
# 4           Someone needs to tell the Democrats that

# %%
#write dataframe into csv file
tweets_to_df.to_csv('tweets_joebiden.csv') 
#reads csv file
savedTweets = pd.read_csv('tweets_joebiden.csv',index_col=0)

# %% [markdown]
# #get subjectivity and polarity of tweets with a function
# def getSubjectivity(text):
#     return TextBlob(text).sentiment.subjectivity
# #get polarity with a function
# def getPolarity(text):
#     return TextBlob(text).sentiment.polarity
# savedTweets['Subjectivity'] = savedTweets['cleanedTweets'].apply(getSubjectivity)
# savedTweets['Polarity'] = savedTweets['cleanedTweets'].apply(getPolarity)
# savedTweets.drop('Tweets', axis=1).head() #shows polarity and subjectivity of each tweet and drops the uncleaned tweets column

# %%
#create a function to check negative, neutral and positive analysis
def getAnalysis(score):
    if score<0:
        return 'Negative'
    elif score ==0:
        return 'Neutral'
    else:
        return 'Positive'
    
savedTweets['Analysis'] = savedTweets['Polarity'].apply(getAnalysis)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Polarity'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-e391b62d0f83> in <module>
#       8         return 'Positive'
#       9
# ---> 10 savedTweets['Analysis'] = savedTweets['Polarity'].apply(getAnalysis)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'Polarity'

# %%
savedTweets['Analysis'].value_counts() #shows the counts of tweets' polarity

# %%
#plot a bar graph to show count of tweet sentiment
fig = plt.figure(figsize=(7,5))
color = ['green','grey','red']
savedTweets['Analysis'].value_counts().plot(kind='bar',color = color)
plt.title('Value count of tweet polarity')
plt.ylabel('Count')
plt.xlabel('Polarity')
plt.grid(False)
plt.show()

# %%
#pie chart to show percentage distribution of polarity
fig = plt.figure(figsize=(7,7))
colors = ('green', 'grey', 'red')
wp={'linewidth':2, 'edgecolor': 'black'}
tags=savedTweets['Analysis'].value_counts()
explode = (0.1,0.1,0.1)
tags.plot(kind='pie', autopct='%1.1f%%', shadow=True, colors=colors, 
         startangle=90, wedgeprops=wp, explode=explode, label='')
plt.title('Distribution of polarity')

# %%
#plot the polarity and subjectivity on a scatter plot
plt.figure(figsize=(9,7))
for i in range(0,savedTweets.shape[0]):
    plt.scatter(savedTweets['Polarity'][i],savedTweets['Subjectivity'][i], color='blue')
plt.title('Sentiment Analysis')
plt.xlabel('Polarity')
plt.ylabel('Subjectivity')
plt.show()

# %%
#create a function for wordcloud
def create_wordcloud(text):    
    allWords = ' '.join([tweets for tweets in text])
    wordCloud = WordCloud(background_color='white', width=800, height=500, random_state=21, max_font_size=130).generate(allWords)
    plt.figure(figsize=(20,10))
    plt.imshow(wordCloud)
    plt.axis('off')
    plt.show()
#wordcloud for positive tweets
posTweets = savedTweets.loc[savedTweets['Analysis']=='Positive', 'cleanedTweets']
create_wordcloud(posTweets)
#wordcloud for negative tweets
negTweets = savedTweets.loc[savedTweets['Analysis']=='Negative', 'cleanedTweets']
create_wordcloud(negTweets)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Analysis'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-c0c12717a8d6> in <module>
#       8     plt.show()
#       9 #wordcloud for positive tweets
# ---> 10 posTweets = savedTweets.loc[savedTweets['Analysis']=='Positive', 'cleanedTweets']
#      11 create_wordcloud(posTweets)
#      12 #wordcloud for negative tweets
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'Analysis'
